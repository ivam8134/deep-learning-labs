# %%
 ! pip install tensorflow keras
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp313-cp313-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Collecting keras
#   Using cached keras-3.13.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (24.2)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.34.0-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.78.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from tensorflow) (3.12.1)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/athena/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/athena/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/athena/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/athena/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: rich in /home/athena/anaconda3/lib/python3.13/site-packages (from keras) (13.9.4)
# Collecting namex (from keras)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras)
#   Using cached optree-0.19.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/athena/anaconda3/lib/python3.13/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/athena/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Downloading tensorflow-2.21.0-cp313-cp313-manylinux_2_27_x86_64.whl (572.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.9/572.9 MB 6.9 MB/s  0:01:46 eta 0:00:010:00:03m
# Downloading grpcio-1.78.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 7.1 MB/s  0:00:007.1 MB/s eta 0:00:01:01
# Downloading ml_dtypes-0.5.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 7.4 MB/s  0:00:007.4 MB/s eta 0:00:01
# Downloading protobuf-7.34.0-cp310-abi3-manylinux2014_x86_64.whl (324 kB)
# Downloading keras-3.13.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.6 MB/s  0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 7.3 MB/s  0:00:037.3 MB/s eta 0:00:01:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (456 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, protobuf, optree, opt_einsum, ml_dtypes, grpcio, google_pasta, gast, astunparse, absl-py, keras, tensorflow
#   Attempting uninstall: protobuf2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [libclang]
#     Found existing installation: protobuf 5.29.338;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [libclang]
#     Uninstalling protobuf-5.29.3:;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [libclang]
#       Successfully uninstalled protobuf-5.29.3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [libclang]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [tensorflow]0m 14/15 [tensorflow]s]uf]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.45.1 requires protobuf<7,>=3.20, but you have protobuf 7.34.0 which is incompatible.
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.78.0 keras-3.13.2 libclang-18.1.1 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.0 tensorflow-2.21.0 termcolor-3.3.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow import keras

print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773268160.348145    6061 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1773268160.348501    6061 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1773268160.378853    6061 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773268161.147672    6061 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1773268161.147882    6061 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# TensorFlow: 2.21.0
# Keras: 3.13.2
